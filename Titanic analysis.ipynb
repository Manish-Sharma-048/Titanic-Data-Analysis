# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.gender.value_counts()
# Out:
# male      577
# female    314
# Name: gender, dtype: int64

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df[df.Survived == 1].gender.value_counts()
# Out:
# female    233
# male      109
# Name: gender, dtype: int64

# %%
df[df.Survived == 1].SibSp.value_counts()
# Out:
# 0    210
# 1    112
# 2     13
# 3      4
# 4      3
# Name: SibSp, dtype: int64

# %%
df[df.Survived == 1].Parch.value_counts()
# Out:
# 0    233
# 1     65
# 2     40
# 3      3
# 5      1
# Name: Parch, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sur = df[df.Survived == 1]
sur
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name  gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
sur.describe()
# Out:
#        PassengerId  Survived      Pclass         Age       SibSp       Parch  \
# count   342.000000     342.0  342.000000  290.000000  342.000000  342.000000
# mean    444.368421       1.0    1.950292   28.343690    0.473684    0.464912
# std     252.358840       0.0    0.863321   14.950952    0.708688    0.771712
# min       2.000000       1.0    1.000000    0.420000    0.000000    0.000000
# 25%     250.750000       1.0    1.000000   19.000000    0.000000    0.000000
# 50%     439.500000       1.0    2.000000   28.000000    0.000000    0.000000
# 75%     651.500000       1.0    3.000000   36.000000    1.000000    1.000000
# max     890.000000       1.0    3.000000   80.000000    4.000000    5.000000
#
#              Fare
# count  342.000000
# mean    48.395408
# std     66.596998
# min      0.000000
# 25%     12.475000
# 50%     26.000000
# 75%     57.000000
# max    512.329200

# %%
sur[sur.Age<=19].Age.value_counts()
# Out:
# 18.00    9
# 19.00    9
# 4.00     7
# 17.00    6
# 16.00    6
# 1.00     5
# 3.00     5
# 15.00    4
# 5.00     4
# 14.00    3
# 2.00     3
# 8.00     2
# 9.00     2
# 13.00    2
# 0.75     2
# 6.00     2
# 0.83     2
# 0.42     1
# 12.00    1
# 7.00     1
# 11.00    1
# 0.92     1
# 0.67     1
# Name: Age, dtype: int64

# %%
sur[(sur.Age>19) & (sur.Age<=28)].Age.value_counts()
# Out:
# 24.0    15
# 22.0    11
# 27.0    11
# 28.0     7
# 25.0     6
# 26.0     6
# 23.0     5
# 21.0     5
# 20.0     3
# Name: Age, dtype: int64

# %%
sur[(sur.Age>28) & (sur.Age<=36)].Age.value_counts()
# Out:
# 36.0    11
# 35.0    11
# 30.0    10
# 32.0     9
# 31.0     8
# 29.0     8
# 33.0     6
# 34.0     6
# 32.5     1
# Name: Age, dtype: int64

# %%
sur[(sur.Age>36) & (sur.Age<=80)].Age.value_counts()
# Out:
# 42.0    6
# 48.0    6
# 40.0    6
# 45.0    5
# 50.0    5
# 39.0    5
# 38.0    5
# 49.0    4
# 54.0    3
# 52.0    3
# 58.0    3
# 44.0    3
# 51.0    2
# 60.0    2
# 63.0    2
# 41.0    2
# 62.0    2
# 56.0    2
# 55.0    1
# 80.0    1
# 37.0    1
# 43.0    1
# 53.0    1
# 47.0    1
# Name: Age, dtype: int64

# %%
sur
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name  gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
sur.Fare.mean()
# Out:
# 48.39540760233917

# %%
sur.describe()
# Out:
#        PassengerId  Survived      Pclass         Age       SibSp       Parch  \
# count   342.000000     342.0  342.000000  290.000000  342.000000  342.000000
# mean    444.368421       1.0    1.950292   28.343690    0.473684    0.464912
# std     252.358840       0.0    0.863321   14.950952    0.708688    0.771712
# min       2.000000       1.0    1.000000    0.420000    0.000000    0.000000
# 25%     250.750000       1.0    1.000000   19.000000    0.000000    0.000000
# 50%     439.500000       1.0    2.000000   28.000000    0.000000    0.000000
# 75%     651.500000       1.0    3.000000   36.000000    1.000000    1.000000
# max     890.000000       1.0    3.000000   80.000000    4.000000    5.000000
#
#              Fare
# count  342.000000
# mean    48.395408
# std     66.596998
# min      0.000000
# 25%     12.475000
# 50%     26.000000
# 75%     57.000000
# max    512.329200

# %%
sur.Pclass.value_counts(sur.Age)
# Out:
# 1    136
# 3    119
# 2     87
# Name: Pclass, dtype: int64

# %%
sur[(sur.Survived == 1) & ((sur.Pclass == 3) & (sur.Embarked == "S") & (sur.gender == 'male'))].count()
# Out:
# PassengerId    34
# Survived       34
# Pclass         34
# Name           34
# gender         34
# Age            30
# SibSp          34
# Parch          34
# Ticket         34
# Fare           34
# Cabin           2
# Embarked       34
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df.Survived == 1) & (df.gender == 'male')].count()
# Out:
# PassengerId    109
# Survived       109
# Pclass         109
# Name           109
# gender         109
# Age             93
# SibSp          109
# Parch          109
# Ticket         109
# Fare           109
# Cabin           45
# Embarked       109
# dtype: int64
